# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font',family='Malgun Gothic')

# %%
from statsmodels.formula.api import ols

# %%
# !move "D:DIAMOND\Downloads\독수리\picher_stats_2017.csv"
# Out:
# 지정된 파일을 찾을 수 없습니다.

# %%
df = pd.read_csv('file-path/data/picher_stats_2017.csv')
df.shape
# Out:
# (152, 22)

# %%
df.head()
# Out:
#    선수명   팀명   승   패  세  홀드  블론  경기  선발     이닝  ...  홈런/9  BABIP  LOB%   ERA  \
# 0   켈리   SK  16   7  0   0   0  30  30  190.0  ...  0.76  0.342  73.7  3.60
# 1   소사   LG  11  11  1   0   0  30  29  185.1  ...  0.53  0.319  67.1  3.88
# 2  양현종  KIA  20   6  0   0   0  31  31  193.1  ...  0.79  0.332  72.1  3.44
# 3  차우찬   LG  10   7  0   0   0  28  28  175.2  ...  1.02  0.298  75.0  3.43
# 4  레일리   롯데  13   7  0   0   0  30  30  187.1  ...  0.91  0.323  74.1  3.80
#
#    RA9-WAR   FIP  kFIP   WAR  연봉(2018)  연봉(2017)
# 0     6.91  3.69  3.44  6.62    140000     85000
# 1     6.80  3.52  3.41  6.08    120000     50000
# 2     6.54  3.94  3.82  5.64    230000    150000
# 3     6.11  4.20  4.03  4.63    100000    100000
# 4     6.13  4.36  4.31  4.38    111000     85000
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['선수명', '팀명', '승', '패', '세', '홀드', '블론', '경기', '선발', '이닝', '삼진/9',
#        '볼넷/9', '홈런/9', 'BABIP', 'LOB%', 'ERA', 'RA9-WAR', 'FIP', 'kFIP', 'WAR',
#        '연봉(2018)', '연봉(2017)'],
#       dtype='object')

# %% [markdown]
# 그럼 여기서 우리는 y는 무엇인지, x는 무엇인지 알 수 있습니다.
#
#
#
# y=연봉(2018)
#
# x=그 외
#
#
#
# 어떤 x가 중요한지 찾는 과정을 진행하겠습니다.

# %%
df['연봉(2018)'].hist(bins=100)

# %%
sns.boxplot(data=df,x='연봉(2018)')

# %% [markdown]
# 제일 먼저 할 일은, 단위를 통일하는 것입니다.
#
# 현재 테이블은 각 특징(x)의 자릿수가 서로 다르기에, scaling작업을 통해 같은 범위로 압축시켜야 합니다.
#
# == 표준화

# %%
def standard_scaling(df,columnlist):
    for i in columnlist:
        mean=df[i].mean()
        sd=df[i].std()
        df[i]=df[i].apply(lambda x: (x-mean)/sd)
    return df

# %%
cl = df.columns.tolist()

# %%
cl=cl[2:]

# %%
standard_scaling(df,cl)
# Out:
#      선수명   팀명         승         패         세        홀드        블론        경기  \
# 0     켈리   SK  3.313623  1.227145 -0.306452 -0.585705 -0.543592  0.059433
# 1     소사   LG  2.019505  2.504721 -0.098502 -0.585705 -0.543592  0.059433
# 2    양현종  KIA  4.348918  0.907751 -0.306452 -0.585705 -0.543592  0.111056
# 3    차우찬   LG  1.760682  1.227145 -0.306452 -0.585705 -0.543592 -0.043811
# 4    레일리   롯데  2.537153  1.227145 -0.306452 -0.585705 -0.543592  0.059433
# ..   ...  ...       ...       ...       ...       ...       ...       ...
# 147  장민재   한화 -0.309907  0.588357 -0.306452 -0.585705  0.680497  0.214300
# 148  정용운  KIA -0.051084 -0.369825 -0.306452 -0.585705 -0.543592 -0.198678
# 149  노경은   롯데 -0.827554 -0.369825 -0.306452 -0.585705 -0.543592 -1.024633
# 150  김승현   삼성 -0.827554 -0.050431 -0.306452 -0.364245 -0.543592  0.627278
# 151  류희운   KT  0.207740  0.268963 -0.306452 -0.585705 -0.543592 -0.250300
#
#            선발        이닝  ...      홈런/9     BABIP      LOB%       ERA  \
# ...

# %%
df
# Out:
#      선수명   팀명         승         패         세        홀드        블론        경기  \
# 0     켈리   SK  3.313623  1.227145 -0.306452 -0.585705 -0.543592  0.059433
# 1     소사   LG  2.019505  2.504721 -0.098502 -0.585705 -0.543592  0.059433
# 2    양현종  KIA  4.348918  0.907751 -0.306452 -0.585705 -0.543592  0.111056
# 3    차우찬   LG  1.760682  1.227145 -0.306452 -0.585705 -0.543592 -0.043811
# 4    레일리   롯데  2.537153  1.227145 -0.306452 -0.585705 -0.543592  0.059433
# ..   ...  ...       ...       ...       ...       ...       ...       ...
# 147  장민재   한화 -0.309907  0.588357 -0.306452 -0.585705  0.680497  0.214300
# 148  정용운  KIA -0.051084 -0.369825 -0.306452 -0.585705 -0.543592 -0.198678
# 149  노경은   롯데 -0.827554 -0.369825 -0.306452 -0.585705 -0.543592 -1.024633
# 150  김승현   삼성 -0.827554 -0.050431 -0.306452 -0.364245 -0.543592  0.627278
# 151  류희운   KT  0.207740  0.268963 -0.306452 -0.585705 -0.543592 -0.250300
#
#            선발        이닝  ...      홈런/9     BABIP      LOB%       ERA  \
# ...

# %%
df = df.rename(columns={'연봉(2018)': 'y'})
df.columns
# Out:
# Index(['선수명', '팀명', '승', '패', '세', '홀드', '블론', '경기', '선발', '이닝', '삼진/9',
#        '볼넷/9', '홈런/9', 'BABIP', 'LOB%', 'ERA', 'RA9-WAR', 'FIP', 'kFIP', 'WAR',
#        'y', '연봉(2017)'],
#       dtype='object')

# %%
df = df.drop(columns='선수명')

# %%
team_encoding = pd.get_dummies(df['팀명'])

# %%
df = df.join(team_encoding)

# %%
res = ols('y~승',data=df).fit()

# %%
df.columns
# Out:
# Index(['팀명', '승', '패', '세', '홀드', '블론', '경기', '선발', '이닝', '삼진/9', '볼넷/9',
#        '홈런/9', 'BABIP', 'LOB%', 'ERA', 'RA9-WAR', 'FIP', 'kFIP', 'WAR', 'y',
#        '연봉(2017)', 'KIA', 'KT', 'LG', 'NC', 'SK', '두산', '롯데', '삼성', '한화'],
#       dtype='object')

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     154.6
# Date:                Sat, 14 Nov 2020   Prob (F-statistic):           7.61e-25
# Time:                        21:17:34   Log-Likelihood:                -161.33
# No. Observations:                 152   AIC:                             326.7
# Df Residuals:                     150   BIC:                             332.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.255e-17      0.057  -3.95e-16      1.000      -0.113       0.113
# ...
